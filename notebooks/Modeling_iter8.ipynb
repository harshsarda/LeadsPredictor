# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import os
import warnings
import sys
import matplotlib.pyplot as plt

# %%
sys.path.append('/home/mondzi259/Apna_Assignment/src/ml_auto/')

# %%
from custom_estimator import Estimator, scoring_metric
from encoding import FreqeuncyEncoding,TargetEncoding
from hyperopt_model_selection import HyperOptModelSelection,hp
from custom_fold_generator import KFold,GroupKFold,CustomFolds
from lightgbm import LGBMRegressor

# %%
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
DATA_DIR = '/home/mondzi259/Apna_Assignment/data/'

# %%
df = pd.read_excel(os.path.join(DATA_DIR,'data.xlsx'),sheet_name=0)
df.shape
# Out:
# (30000, 19)

# %%
df.drop('feebackgiven',axis=1,inplace=True)

# %%
data_dic = pd.read_excel(os.path.join(DATA_DIR,'data.xlsx'),sheet_name=1,header=None)

# %%
data_dic
# Out:
#                      0                                                  1                                                  2                                                  3
# 0                 lead  A candidate who has interacted with HR on the ...                                                NaN                                                NaN
# 1                shift                                         night/ day                                0 - day, 1 - night                                                 NaN
# 2               gender                                            f/m/all               0 -  male jobs, 1 - female , 2 - all                                                NaN
# 3            education                                        10th to PG   ordinally placed, 10th being lowest and PG the...                                                NaN
# 4           created_on                                   job created date                  Days since a fixed reference data  For ex: if reference data was 1 Jan 2020,\njob...
# 5        employer_type       key-account/ smb/ enterprise/ consultant/ NA  most jobs are smb, followed by Key accounts, e...                                                NaN
# 6   applicant_location                        candidate distance from job    lower the value, lower the distance requirement                                                NaN
# 7                 city                                               city                                          is masked                                                NaN
# 8                 area                                               area                                          is masked                                                NaN
# 9         organization                                       company name                                          is masked                                                NaN
# 10             deposit                                 requires a deposit                   majority don't require a deposit                          actual amounts are masked
# 11            category                                delivery/driver/...                                          is masked                                                NaN
# 12             english              no/broken-english/good-english/fluent  higher the value, higher the quality of englis...                                                NaN
# 13        num_openings                            no of people to recruit                                                NaN                                                NaN
# 14          max_salary                                             salary                                              as is                                                NaN
# 15        is_part_time                                             yes/no                        majority are full time jobs                                                NaN
# 16       feedbackgiven                                             yes/no                  majority don't have feedbackgiven                                                NaN
# 17   leads_per_opening                                                NaN                    leads/ num_openings for the job                                                NaN
# 18                 dow                                    day of the week                                                NaN                                                NaN

# %%
df.head()
# Out:
#    shift  gender  education  created_on  dow  employer_type  applicant_location  city    area  organization  deposit  category  english  num_openings  max_salary  min_salary  is_part_time  leads_per_opening
# 0    0.0     0.0        3.0       413.0  3.0            0.0                 0.0   1.0  4119.0       31278.0      0.0      55.0      2.0          22.0     21000.0         NaN           0.0           0.090909
# 1    0.0     0.0        3.0       529.0  0.0            4.0                 0.0   2.0  2017.0       32006.0      0.0      54.0      2.0           2.0     80000.0         NaN           0.0          31.500000
# 2    0.0     0.0        0.0       457.0  0.0            4.0                 0.0   3.0  1500.0       32029.0      0.0      42.0      3.0           1.0      3500.0         NaN           1.0           9.000000
# 3    0.0     0.0        4.0       450.0  3.0            4.0                 0.0   5.0   638.0        9925.0      0.0      60.0      4.0           4.0     11500.0         NaN           0.0           0.000000
# 4    0.0     0.0        0.0       480.0  0.0            1.0                 0.0   2.0  4115.0        8400.0      0.0      16.0      3.0          25.0     25000.0         NaN           0.0           1.400000

# %% [markdown]
# ### Target vs created_on

# %%
df.groupby(pd.qcut(df['created_on'],10,
                   duplicates='drop',labels=False))['leads_per_opening'].mean().plot()
plt.ylabel('leads_per_opening')
plt.title('Decile Plot of leads_per_opening vs created_on');

# %% [markdown]
# ###

# %%
num_cols = ['leads_per_opening','max_salary','min_salary','deposit','num_openings','created_on']
cat_cols = [i for i in df.columns.tolist() if i not in num_cols]
cat_ordinal_cols = ['applicant_location','english','education']
cat_non_ord_cols = [i for i in cat_cols if i not in cat_ordinal_cols]

# %%
cat_non_ord_cols,cat_ordinal_cols
# Out:
# (['shift',
#   'gender',
#   'dow',
#   'employer_type',
#   'city',
#   'area',
#   'organization',
#   'category',
#   'is_part_time'],
#  ['applicant_location', 'english', 'education'])

# %%
df[cat_cols].nunique()
# Out:
# shift                     2
# gender                    3
# education                 6
# dow                       7
# employer_type             5
# applicant_location        4
# city                      7
# area                   2740
# organization          14886
# category                 67
# english                   4
# is_part_time              2
# dtype: int64

# %%
class FreqEnc:
    def __init__(self,cat_freq_cols):
        self.cat_freq_cols = cat_freq_cols
    def fit(self,df):
        self.freq_encoding_dict = {
                x: df[x].value_counts(1).to_dict() for x in self.cat_freq_cols
            }
    def transform(self,df):
        for col in self.cat_freq_cols:
            df[col+"_fe"] = df[col].map(self.freq_encoding_dict[col]).fillna(0)
        return df
    def fit_transform(self,df):
        self.fit(df)
        return self.transform(df)

# %%
df=df.sort_values('created_on').reset_index(drop=True)

# %%
df.shape
# Out:
# (30000, 18)

# %%
df['target'] = np.log1p(df.leads_per_opening)

# %%
fig, axes = plt.subplots(1, 2, figsize=(6, 4))
df.leads_per_opening.hist(ax=axes[0])
axes[0].set_title('leads_per_opening')
df.target.hist(ax=axes[1])
axes[1].set_title('log1p leads_per_opening')
plt.tight_layout()

# %%
df.target.describe()
# Out:
# count    30000.000000
# mean         1.507317
# std          1.264234
# min          0.000000
# 25%          0.385158
# 50%          1.299283
# 75%          2.397895
# max          6.559615
# Name: target, dtype: float64

# %%
folds =[
    (df[(df.created_on<=df.created_on.quantile(0.7))].index.tolist(),\
df[(df.created_on>df.created_on.quantile(0.7))&\
      (df.created_on<=df.created_on.quantile(0.8))].index.tolist()),
    
    (df[(df.created_on>=df.created_on.quantile(0.1))&\
      (df.created_on<=df.created_on.quantile(0.8))].index.tolist(),\
df[(df.created_on>df.created_on.quantile(0.8))&\
      (df.created_on<=df.created_on.quantile(0.9))].index.tolist()),
    
    (df[(df.created_on>=df.created_on.quantile(0.2))&\
      (df.created_on<=df.created_on.quantile(0.9))].index.tolist(),\
df[(df.created_on>df.created_on.quantile(0.9))&\
      (df.created_on<=df.created_on.quantile(1))].index.tolist())
]

# %%
[(df.iloc[i].shape,df.iloc[j].shape) for i,j in folds]
# Out:
# [((21137, 19), (3031, 19)),
#  ((21191, 19), (2865, 19)),
#  ((21073, 19), (2967, 19))]

# %%
target = df.target.values

# %%
fe = FreqEnc(cat_freq_cols=cat_non_ord_cols)

df = fe.fit_transform(df)

# %%
(df['max_salary']-df.min_salary).describe()
# Out:
# count     4117.000000
# mean      6104.805441
# std       6419.603169
# min      -2000.000000
# 25%       2000.000000
# 50%       5000.000000
# 75%       7500.000000
# max      96399.000000
# dtype: float64

# %%
df.shape
# Out:
# (30000, 28)

# %%
df[cat_non_ord_cols].nunique()
# Out:
# shift                2
# gender               3
# dow                  7
# employer_type        5
# city                 7
# area              2740
# organization     14886
# category            67
# is_part_time         2
# dtype: int64

# %%
df[cat_ordinal_cols].nunique()
# Out:
# applicant_location    4
# english               4
# education             6
# dtype: int64

# %% [markdown]
# ### Adding cat-cat interactions

# %%
def get_derived_cat(df,a,b):
    df[a+'_'+b]= df[a].astype('str') + '_' + df[b].astype('str')
    return df

# %%
def gen_cat_cat(df):
    df = get_derived_cat(df,'category','organization')
    df = get_derived_cat(df,'category','area')
    df = get_derived_cat(df,'category','city')
    df = get_derived_cat(df,'category','dow')
    df = get_derived_cat(df,'category','employer_type')
    
    df = get_derived_cat(df,'organization','area')
    df = get_derived_cat(df,'organization','city')
    df = get_derived_cat(df,'organization','dow')
    df = get_derived_cat(df,'organization','employer_type')
    
    df = get_derived_cat(df,'area','city')
    df = get_derived_cat(df,'area','dow')
    df = get_derived_cat(df,'area','employer_type')
    
    df = get_derived_cat(df,'city','dow')
    df = get_derived_cat(df,'city','employer_type')
    
    df = get_derived_cat(df,'dow','employer_type')
    
    return df

# %%
df = gen_cat_cat(df)

# %%
cat_cat_cols = ['category_organization', 'category_area', 'category_city', 'category_dow',
                'category_employer_type', 'organization_area', 'organization_city', 'organization_dow', 
                'organization_employer_type', 'area_city', 'area_dow', 'area_employer_type', 'city_dow',
               'city_employer_type', 'dow_employer_type']

# %%
fe2 = FreqEnc(cat_freq_cols=['category_city'])

df = fe2.fit_transform(df)

# %%
class CatNumAgg:
    def __init__(self,agg_cols, agg_funcs, grpby_cols):
        self.agg_cols=agg_cols
        self.agg_funcs=agg_funcs
        self.grpby_cols=grpby_cols
    def fit(self,df):
        self.encoding_dict={}
        for grp_col in self.grpby_cols:
            agg_df = df.groupby(grp_col)[self.agg_cols].agg(self.agg_funcs).reset_index()
            agg_df.columns = [grp_col] + [
                i + "_" + j + "_grpby" + "_and_" + grp_col
                for i in self.agg_cols
                for j in self.agg_funcs
            ]
            self.encoding_dict[grp_col]=agg_df.to_dict()
    def transform(self,df):
        for k in self.encoding_dict:
            agg_df = pd.DataFrame(self.encoding_dict[k])
            df = df.merge(agg_df, on=k, how="left")
        return df
    def fit_transform(self,df):
        self.fit(df)
        return self.transform(df)

# %%
imp_num_cols = ['num_openings','max_salary','min_salary','education','applicant_location']
agg_funcs = ['mean','std','min','max','median']
cat_agg_cols = ['category','organization','area','category_city',
                'category_dow','city',
                'employer_type']

# %%
catnumagg = CatNumAgg(agg_cols= imp_num_cols,agg_funcs=agg_funcs, grpby_cols=cat_agg_cols)

# %%
df = catnumagg.fit_transform(df)

# %%
df.shape
# Out:
# (30000, 202)

# %%
def perform_cat_cat_agg(df,grpby_cols,agg_cols,agg_funcs,agg_func_names=['mode']):
    agg_df = df.groupby(grpby_cols)[agg_cols].agg(agg_funcs).reset_index()
    agg_df.columns = grpby_cols + [
        i + "_" + j + "_grpby_" + "_and_".join(grpby_cols)
        for i in agg_cols
        for j in agg_func_names
    ]
    return df.merge(agg_df, on=grpby_cols, how="left")

# %%
df = perform_cat_cat_agg(df,['area'],['organization'],
                    [lambda x: x.value_counts().index[0]])
# df = perform_cat_cat_agg(df,['city'],['organization','category','area','dow'],
#                     ['nunique',lambda x: x.value_counts().index[0]])

# %%
df.shape
# Out:
# (30000, 203)

# %%
# df = perform_cat_cat_agg(df,['employer_type'],['category','dow','organization'],
#                     ['nunique',lambda x: x.value_counts().index[0]])
# df = perform_cat_cat_agg(df,['applicant_location'],['organization','category','area','dow'],
#                     ['nunique',lambda x: x.value_counts().index[0]])

# %%
# df = perform_cat_cat_agg(df,['gender'],['category','dow','organization'],
#                     ['nunique',lambda x: x.value_counts().index[0]])
# df = perform_cat_cat_agg(df,['english'],['organization','category','area','dow'],
#                     ['nunique',lambda x: x.value_counts().index[0]])

# %%
uniq_cols = df.columns[df.nunique(dropna=False)==1]
len(uniq_cols)
# Out:
# 0

# %%
df.drop(uniq_cols,axis=1,inplace=True)

# %%
remove_cols = cat_non_ord_cols + ['target','leads_per_opening'] + cat_cat_cols
use_cols = [i for i in df.columns if i not in remove_cols]

# %%
drop_cols = df.columns[df.columns.str.contains('nunique') | df.columns.str.contains('mode')]

# %%
# df.drop(drop_cols,axis=1,inplace=True)

# %%
use_cols = [i for i in use_cols if i not in drop_cols]

# %%
params = {'boosting_type': 'gbdt',
 'colsample_bytree': 0.8,
 'learning_rate': 0.1,
 'min_child_samples': 120,
 'n_estimators': 10000,
 'n_jobs': -1,
 'num_leaves': 16,
 'objective': 'regression',
 'subsample': 0.8,
 'subsample_freq': 10}

# %%
est = Estimator(model=LGBMRegressor(**params),
               early_stopping_rounds=100,
               validation_scheme=folds,
               shuffle=True)

# %%
est.get_repeated_out_of_folds(df[use_cols].values,target)
# Out:
# [100]	valid_0's rmse: 0.894347	valid_0's l2: 0.799857	valid_1's rmse: 0.805084	valid_1's l2: 0.648159
# [200]	valid_0's rmse: 0.890303	valid_0's l2: 0.79264	valid_1's rmse: 0.754139	valid_1's l2: 0.568726
# [100]	valid_0's rmse: 0.834886	valid_0's l2: 0.697034	valid_1's rmse: 0.806274	valid_1's l2: 0.650078
# [200]	valid_0's rmse: 0.829819	valid_0's l2: 0.688599	valid_1's rmse: 0.755737	valid_1's l2: 0.571139
# [300]	valid_0's rmse: 0.828679	valid_0's l2: 0.686709	valid_1's rmse: 0.719705	valid_1's l2: 0.517975
# [400]	valid_0's rmse: 0.830134	valid_0's l2: 0.689122	valid_1's rmse: 0.68802	valid_1's l2: 0.473371
# [100]	valid_0's rmse: 0.873277	valid_0's l2: 0.762612	valid_1's rmse: 0.8024	valid_1's l2: 0.643846
# [200]	valid_0's rmse: 0.869807	valid_0's l2: 0.756565	valid_1's rmse: 0.751098	valid_1's l2: 0.564149
# {'cv_scores': [0.8884260455116506, 0.8277062413414091, 0.8684975120286321],
#  'avg_cv_score': 0.8615432662938973,
#  'std_scores': 0.02527178670536806,
#  'overall_cv_score': 1.71385676246552,
#  'eval_score': 0.8615432662938973}

# %%
feat_imps = est.feature_importances(columns = use_cols) 
feat_imps['cum_imp']=feat_imps.feature_importance.cumsum()
feat_imps
# Out:
#                                                 column  feature_importance  rank   cum_imp
# 5                                         num_openings            0.039458     1  0.039458
# 6                                           max_salary            0.039068     2  0.078525
# 1                                           created_on            0.032771     3  0.111296
# 0                                            education            0.030072     4  0.141368
# 4                                              english            0.024283     5  0.165652
# 82                        education_std_grpby_and_area            0.021910     6  0.187562
# 111    applicant_location_mean_grpby_and_category_city            0.019690     7  0.207252
# 42             num_openings_std_grpby_and_organization            0.018776     8  0.226027
# 47               max_salary_std_grpby_and_organization            0.016791     9  0.242818
# 48               max_salary_min_grpby_and_organization            0.016560    10  0.259378
# 77                       min_salary_std_grpby_and_area            0.016546    11  0.275924
# 91           num_openings_mean_grpby_and_category_city            0.016434    12  0.292358
# 41            num_openings_mean_grpby_and_organization            0.016226    13  0.308585
# 76                      min_salary_mean_grpby_and_area            0.016170    14  0.324755
# 72                       max_salary_std_grpby_and_area            0.015544    15  0.340299
# 67                     num_openings_std_grpby_and_area            0.014529    16  0.354828
# 66                    num_openings_mean_grpby_and_area            0.013847    17  0.368675
# 38          applicant_location_mean_grpby_and_category            0.013802    18  0.382476
# 46              max_salary_mean_grpby_and_organization            0.013715    19  0.396192
# 71                      max_salary_mean_grpby_and_area            0.013436    20  0.409627
# 107              education_std_grpby_and_category_city            0.013304    21  0.422932
# 112     applicant_location_std_grpby_and_category_city            0.013060    22  0.435992
# 57                education_std_grpby_and_organization            0.012915    23  0.448906
# 87               applicant_location_std_grpby_and_area            0.012619    24  0.461525
# 81                       education_mean_grpby_and_area            0.012383    25  0.473908
# 14                                     organization_fe            0.011943    26  0.485851
# 15                                         category_fe            0.011658    27  0.497509
# 92            num_openings_std_grpby_and_category_city            0.011497    28  0.509005
# 86              applicant_location_mean_grpby_and_area            0.011257    29  0.520263
# 97              max_salary_std_grpby_and_category_city            0.011126    30  0.531389
# 33                   education_mean_grpby_and_category            0.009993    31  0.541381
# 137      applicant_location_std_grpby_and_category_dow            0.009812    32  0.551194
# 102             min_salary_std_grpby_and_category_city            0.009611    33  0.560804
# 56               education_mean_grpby_and_organization            0.009606    34  0.570410
# 13                                             area_fe            0.009603    35  0.580013
# 136     applicant_location_mean_grpby_and_category_dow            0.009307    36  0.589320
# 17                                    category_city_fe            0.009074    37  0.598394
# 126             min_salary_mean_grpby_and_category_dow            0.009004    38  0.607398
# 132               education_std_grpby_and_category_dow            0.008952    39  0.616350
# 122              max_salary_std_grpby_and_category_dow            0.008770    40  0.625120
# 106             education_mean_grpby_and_category_city            0.008762    41  0.633882
# 101            min_salary_mean_grpby_and_category_city            0.008585    42  0.642467
# 50            max_salary_median_grpby_and_organization            0.008474    43  0.650941
# 96             max_salary_mean_grpby_and_category_city            0.008308    44  0.659250
# 78                       min_salary_min_grpby_and_area            0.008265    45  0.667515
# 127              min_salary_std_grpby_and_category_dow            0.008246    46  0.675761
# 49               max_salary_max_grpby_and_organization            0.007535    47  0.683295
# 131              education_mean_grpby_and_category_dow            0.007499    48  0.690795
# 80                    min_salary_median_grpby_and_area            0.007440    49  0.698235
# 9                                            gender_fe            0.007411    50  0.705646
# 117            num_openings_std_grpby_and_category_dow            0.007287    51  0.712933
# 25                   max_salary_min_grpby_and_category            0.006753    52  0.719686
# 39           applicant_location_std_grpby_and_category            0.006729    53  0.726415
# 19                 num_openings_std_grpby_and_category            0.006468    54  0.732884
# 73                       max_salary_min_grpby_and_area            0.006347    55  0.739231
# 62       applicant_location_std_grpby_and_organization            0.006264    56  0.745495
# 79                       min_salary_max_grpby_and_area            0.006213    57  0.751707
# 100          max_salary_median_grpby_and_category_city            0.006066    58  0.757773
# 99              max_salary_max_grpby_and_category_city            0.006046    59  0.763819
# 121             max_salary_mean_grpby_and_category_dow            0.005952    60  0.769772
# 18                num_openings_mean_grpby_and_category            0.005727    61  0.775499
# 157             applicant_location_mean_grpby_and_city            0.005644    62  0.781142
# 45          num_openings_median_grpby_and_organization            0.005525    63  0.786668
# 23                  max_salary_mean_grpby_and_category            0.005458    64  0.792126
# 98              max_salary_min_grpby_and_category_city            0.005439    65  0.797565
# 116           num_openings_mean_grpby_and_category_dow            0.005415    66  0.802980
# 28                  min_salary_mean_grpby_and_category            0.005316    67  0.808296
# 59                education_max_grpby_and_organization            0.005273    68  0.813569
# 75                    max_salary_median_grpby_and_area            0.005195    69  0.818764
# 103             min_salary_min_grpby_and_category_city            0.005044    70  0.823808
# 36                    education_max_grpby_and_category            0.004921    71  0.828730
# 24                   max_salary_std_grpby_and_category            0.004784    72  0.833513
# 12                                             city_fe            0.004610    73  0.838123
# 94            num_openings_max_grpby_and_category_city            0.004574    74  0.842697
# 54               min_salary_max_grpby_and_organization            0.004566    75  0.847264
# 55            min_salary_median_grpby_and_organization            0.004515    76  0.851779
# 31                   min_salary_max_grpby_and_category            0.004491    77  0.856270
# 29                   min_salary_std_grpby_and_category            0.004424    78  0.860695
# 10                                              dow_fe            0.004330    79  0.865024
# 129              min_salary_max_grpby_and_category_dow            0.004247    80  0.869271
# 70                  num_openings_median_grpby_and_area            0.004212    81  0.873483
# 2                                   applicant_location            0.004172    82  0.877655
# 74                       max_salary_max_grpby_and_area            0.004077    83  0.881732
# 145                      max_salary_std_grpby_and_city            0.003986    84  0.885718
# 44             num_openings_max_grpby_and_organization            0.003935    85  0.889653
# 130           min_salary_median_grpby_and_category_dow            0.003935    86  0.893588
# 104             min_salary_max_grpby_and_category_city            0.003900    87  0.897488
# 52               min_salary_std_grpby_and_organization            0.003774    88  0.901262
# 123              max_salary_min_grpby_and_category_dow            0.003481    89  0.904743
# 53               min_salary_min_grpby_and_organization            0.003430    90  0.908174
# 124              max_salary_max_grpby_and_category_dow            0.003430    91  0.911604
# 34                    education_std_grpby_and_category            0.003422    92  0.915026
# 64       applicant_location_max_grpby_and_organization            0.003390    93  0.918416
# 26                   max_salary_max_grpby_and_category            0.003280    94  0.921695
# 69                     num_openings_max_grpby_and_area            0.003253    95  0.924948
# 119            num_openings_max_grpby_and_category_dow            0.003213    96  0.928161
# 43             num_openings_min_grpby_and_organization            0.003178    97  0.931338
# 51              min_salary_mean_grpby_and_organization            0.003146    98  0.934484
# 7                                           min_salary            0.003118    99  0.937602
# 141                   num_openings_mean_grpby_and_city            0.002858   100  0.940460
# 105          min_salary_median_grpby_and_category_city            0.002724   101  0.943184
# 61      applicant_location_mean_grpby_and_organization            0.002530   102  0.945714
# 60             education_median_grpby_and_organization            0.002514   103  0.948228
# 128              min_salary_min_grpby_and_category_dow            0.002294   104  0.950522
# 143                 num_openings_median_grpby_and_city            0.002179   105  0.952700
# 85                     education_median_grpby_and_area            0.002135   106  0.954836
# 125           max_salary_median_grpby_and_category_dow            0.002076   107  0.956912
# 30                   min_salary_min_grpby_and_category            0.002060   108  0.958972
# 144                     max_salary_mean_grpby_and_city            0.002001   109  0.960973
# 155                       education_std_grpby_and_city            0.001926   110  0.962899
# 21                 num_openings_max_grpby_and_category            0.001883   111  0.964782
# 11                                    employer_type_fe            0.001792   112  0.966574
# 58                education_min_grpby_and_organization            0.001765   113  0.968339
# 27                max_salary_median_grpby_and_category            0.001741   114  0.970079
# 32                min_salary_median_grpby_and_category            0.001606   115  0.971686
# 174    applicant_location_mean_grpby_and_employer_type            0.001598   116  0.973284
# 22              num_openings_median_grpby_and_category            0.001555   117  0.974839
# 109              education_max_grpby_and_category_city            0.001480   118  0.976319
# 167            min_salary_mean_grpby_and_employer_type            0.001472   119  0.977791
# 84                        education_max_grpby_and_area            0.001429   120  0.979220
# 150                      min_salary_std_grpby_and_city            0.001413   121  0.980633
# 65    applicant_location_median_grpby_and_organization            0.001370   122  0.982003
# 95         num_openings_median_grpby_and_category_city            0.001346   123  0.983349
# 169             min_salary_min_grpby_and_employer_type            0.001160   124  0.984509
# 158              applicant_location_std_grpby_and_city            0.001144   125  0.985653
# 108              education_min_grpby_and_category_city            0.000900   126  0.986553
# 168             min_salary_std_grpby_and_employer_type            0.000892   127  0.987445
# 134               education_max_grpby_and_category_dow            0.000774   128  0.988219
# 110           education_median_grpby_and_category_city            0.000766   129  0.988984
# 159          num_openings_mean_grpby_and_employer_type            0.000766   130  0.989750
# 89               applicant_location_max_grpby_and_area            0.000714   131  0.990464
# 120         num_openings_median_grpby_and_category_dow            0.000714   132  0.991179
# 16                                     is_part_time_fe            0.000714   133  0.991893
# 63       applicant_location_min_grpby_and_organization            0.000706   134  0.992600
# 139      applicant_location_max_grpby_and_category_dow            0.000706   135  0.993306
# 152                      min_salary_max_grpby_and_city            0.000698   136  0.994005
# 148                   max_salary_median_grpby_and_city            0.000647   137  0.994652
# 142                    num_openings_std_grpby_and_city            0.000639   138  0.995291
# 147                      max_salary_max_grpby_and_city            0.000639   139  0.995931
# 90            applicant_location_median_grpby_and_area            0.000639   140  0.996570
# 114     applicant_location_max_grpby_and_category_city            0.000588   141  0.997158
# 135            education_median_grpby_and_category_dow            0.000454   142  0.997612
# 163             max_salary_std_grpby_and_employer_type            0.000446   143  0.998058
# 133               education_min_grpby_and_category_dow            0.000328   144  0.998386
# 68                     num_openings_min_grpby_and_area            0.000320   145  0.998705
# 173              education_std_grpby_and_employer_type            0.000261   146  0.998966
# 149                     min_salary_mean_grpby_and_city            0.000253   147  0.999218
# 170             min_salary_max_grpby_and_employer_type            0.000193   148  0.999412
# 83                        education_min_grpby_and_area            0.000193   149  0.999605
# 37                 education_median_grpby_and_category            0.000193   150  0.999799
# 146                      max_salary_min_grpby_and_city            0.000134   151  0.999933
# 164             max_salary_min_grpby_and_employer_type            0.000067   152  1.000000
# 171          min_salary_median_grpby_and_employer_type            0.000000   153  1.000000
# 166          max_salary_median_grpby_and_employer_type            0.000000   154  1.000000
# 162            max_salary_mean_grpby_and_employer_type            0.000000   155  1.000000
# 161        num_openings_median_grpby_and_employer_type            0.000000   156  1.000000
# 165             max_salary_max_grpby_and_employer_type            0.000000   157  1.000000
# 160           num_openings_std_grpby_and_employer_type            0.000000   158  1.000000
# 172             education_mean_grpby_and_employer_type            0.000000   159  1.000000
# 88               applicant_location_min_grpby_and_area            0.000000   160  1.000000
# 156                    education_median_grpby_and_city            0.000000   161  1.000000
# 154                      education_mean_grpby_and_city            0.000000   162  1.000000
# 153                   min_salary_median_grpby_and_city            0.000000   163  1.000000
# 151                      min_salary_min_grpby_and_city            0.000000   164  1.000000
# 140   applicant_location_median_grpby_and_category_dow            0.000000   165  1.000000
# 138      applicant_location_min_grpby_and_category_dow            0.000000   166  1.000000
# 118            num_openings_min_grpby_and_category_dow            0.000000   167  1.000000
# 115  applicant_location_median_grpby_and_category_city            0.000000   168  1.000000
# 113     applicant_location_min_grpby_and_category_city            0.000000   169  1.000000
# 93            num_openings_min_grpby_and_category_city            0.000000   170  1.000000
# 40           applicant_location_max_grpby_and_category            0.000000   171  1.000000
# 35                    education_min_grpby_and_category            0.000000   172  1.000000
# 20                 num_openings_min_grpby_and_category            0.000000   173  1.000000
# 8                                             shift_fe            0.000000   174  1.000000
# 3                                              deposit            0.000000   175  1.000000
# 175     applicant_location_std_grpby_and_employer_type            0.000000   176  1.000000

# %% [markdown]
# ### Important variables that could be used for further feature engineering in order of importance

# %% [markdown]
# 1. category,area, organization, city, dow
# 2. created_on, max_salary, num_openings, min_salary
# 3. education,english
# 4. employer type
