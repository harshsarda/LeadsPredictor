# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import os
import warnings
import sys
import matplotlib.pyplot as plt

# %%
sys.path.append('/home/mondzi259/Apna_Assignment/src/ml_auto/')

# %%
from custom_estimator import Estimator, scoring_metric
from encoding import FreqeuncyEncoding,TargetEncoding
from hyperopt_model_selection import HyperOptModelSelection,hp
from custom_fold_generator import KFold,GroupKFold,CustomFolds
from lightgbm import LGBMRegressor

# %%
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
DATA_DIR = '/home/mondzi259/Apna_Assignment/data/'

# %%
df = pd.read_excel(os.path.join(DATA_DIR,'data.xlsx'),sheet_name=0)
df.shape
# Out:
# (30000, 19)

# %%
df.drop('feebackgiven',axis=1,inplace=True)

# %%
data_dic = pd.read_excel(os.path.join(DATA_DIR,'data.xlsx'),sheet_name=1,header=None)

# %%
data_dic
# Out:
#                      0                                                  1                                                  2                                                  3
# 0                 lead  A candidate who has interacted with HR on the ...                                                NaN                                                NaN
# 1                shift                                         night/ day                                0 - day, 1 - night                                                 NaN
# 2               gender                                            f/m/all               0 -  male jobs, 1 - female , 2 - all                                                NaN
# 3            education                                        10th to PG   ordinally placed, 10th being lowest and PG the...                                                NaN
# 4           created_on                                   job created date                  Days since a fixed reference data  For ex: if reference data was 1 Jan 2020,\njob...
# 5        employer_type       key-account/ smb/ enterprise/ consultant/ NA  most jobs are smb, followed by Key accounts, e...                                                NaN
# 6   applicant_location                        candidate distance from job    lower the value, lower the distance requirement                                                NaN
# 7                 city                                               city                                          is masked                                                NaN
# 8                 area                                               area                                          is masked                                                NaN
# 9         organization                                       company name                                          is masked                                                NaN
# 10             deposit                                 requires a deposit                   majority don't require a deposit                          actual amounts are masked
# 11            category                                delivery/driver/...                                          is masked                                                NaN
# 12             english              no/broken-english/good-english/fluent  higher the value, higher the quality of englis...                                                NaN
# 13        num_openings                            no of people to recruit                                                NaN                                                NaN
# 14          max_salary                                             salary                                              as is                                                NaN
# 15        is_part_time                                             yes/no                        majority are full time jobs                                                NaN
# 16       feedbackgiven                                             yes/no                  majority don't have feedbackgiven                                                NaN
# 17   leads_per_opening                                                NaN                    leads/ num_openings for the job                                                NaN
# 18                 dow                                    day of the week                                                NaN                                                NaN

# %%
df.head()
# Out:
#    shift  gender  education  created_on  dow  employer_type  applicant_location  city    area  organization  deposit  category  english  num_openings  max_salary  min_salary  is_part_time  leads_per_opening
# 0    0.0     0.0        3.0       413.0  3.0            0.0                 0.0   1.0  4119.0       31278.0      0.0      55.0      2.0          22.0     21000.0         NaN           0.0           0.090909
# 1    0.0     0.0        3.0       529.0  0.0            4.0                 0.0   2.0  2017.0       32006.0      0.0      54.0      2.0           2.0     80000.0         NaN           0.0          31.500000
# 2    0.0     0.0        0.0       457.0  0.0            4.0                 0.0   3.0  1500.0       32029.0      0.0      42.0      3.0           1.0      3500.0         NaN           1.0           9.000000
# 3    0.0     0.0        4.0       450.0  3.0            4.0                 0.0   5.0   638.0        9925.0      0.0      60.0      4.0           4.0     11500.0         NaN           0.0           0.000000
# 4    0.0     0.0        0.0       480.0  0.0            1.0                 0.0   2.0  4115.0        8400.0      0.0      16.0      3.0          25.0     25000.0         NaN           0.0           1.400000

# %% [markdown]
# ### Target vs created_on

# %%
df.groupby(pd.qcut(df['created_on'],10,
                   duplicates='drop',labels=False))['leads_per_opening'].mean().plot()
plt.ylabel('leads_per_opening')
plt.title('Decile Plot of leads_per_opening vs created_on');

# %% [markdown]
# ### Ideas:
#
# 1. CV: Time series, KFold, GKFold
# 2. log transform targets: business sense and outliers
# 3. cat OHE, LE, FE, TE
# 4. cat num agg
# 5. num num agg
# 6. missing min salary; app location=0; imputation w/wo
# 7. bayesian fs
# 8. API
# 9. Explainability
# 10. Local/Global feature importance
# 11. Outliers/score
# 12. clustering, svd, cluster distance
# 13. time based (created on) aggs

# %% [markdown]
# ###

# %%
num_cols = ['leads_per_opening','max_salary','min_salary','deposit','num_openings','created_on']
cat_cols = [i for i in df.columns.tolist() if i not in num_cols]
cat_ordinal_cols = ['applicant_location','english','education']
cat_non_ord_cols = [i for i in cat_cols if i not in cat_ordinal_cols]

# %%
cat_non_ord_cols,cat_ordinal_cols
# Out:
# (['shift',
#   'gender',
#   'dow',
#   'employer_type',
#   'city',
#   'area',
#   'organization',
#   'category',
#   'is_part_time'],
#  ['applicant_location', 'english', 'education'])

# %%
df[cat_cols].nunique()
# Out:
# shift                     2
# gender                    3
# education                 6
# dow                       7
# employer_type             5
# applicant_location        4
# city                      7
# area                   2740
# organization          14886
# category                 67
# english                   4
# is_part_time              2
# dtype: int64

# %%
class FreqEnc:
    def __init__(self,cat_freq_cols):
        self.cat_freq_cols = cat_freq_cols
    def fit(self,df):
        self.freq_encoding_dict = {
                x: df[x].value_counts(1).to_dict() for x in self.cat_freq_cols
            }
    def transform(self,df):
        for col in self.cat_freq_cols:
            df[col+"_fe"] = df[col].map(self.freq_encoding_dict[col]).fillna(0)
        return df
    def fit_transform(self,df):
        self.fit(df)
        return self.transform(df)

# %%
df=df.sort_values('created_on').reset_index(drop=True)

# %%
df.shape
# Out:
# (30000, 18)

# %%
df['target'] = np.log1p(df.leads_per_opening)

# %%
fig, axes = plt.subplots(1, 2, figsize=(6, 4))
df.leads_per_opening.hist(ax=axes[0])
axes[0].set_title('leads_per_opening')
df.target.hist(ax=axes[1])
axes[1].set_title('log1p leads_per_opening')
plt.tight_layout()

# %%
df.target.describe()
# Out:
# count    30000.000000
# mean         1.507317
# std          1.264234
# min          0.000000
# 25%          0.385158
# 50%          1.299283
# 75%          2.397895
# max          6.559615
# Name: target, dtype: float64

# %%
folds =[
    (df[(df.created_on<=df.created_on.quantile(0.7))].index.tolist(),\
df[(df.created_on>df.created_on.quantile(0.7))&\
      (df.created_on<=df.created_on.quantile(0.8))].index.tolist()),
    
    (df[(df.created_on>=df.created_on.quantile(0.1))&\
      (df.created_on<=df.created_on.quantile(0.8))].index.tolist(),\
df[(df.created_on>df.created_on.quantile(0.8))&\
      (df.created_on<=df.created_on.quantile(0.9))].index.tolist()),
    
    (df[(df.created_on>=df.created_on.quantile(0.2))&\
      (df.created_on<=df.created_on.quantile(0.9))].index.tolist(),\
df[(df.created_on>df.created_on.quantile(0.9))&\
      (df.created_on<=df.created_on.quantile(1))].index.tolist())
]

# %%
[(df.iloc[i].shape,df.iloc[j].shape) for i,j in folds]
# Out:
# [((21137, 19), (3031, 19)),
#  ((21191, 19), (2865, 19)),
#  ((21073, 19), (2967, 19))]

# %%
target = df.target.values

# %%
fe = FreqEnc(cat_freq_cols=cat_non_ord_cols)

df = fe.fit_transform(df)

# %%
(df['max_salary']-df.min_salary).describe()
# Out:
# count     4117.000000
# mean      6104.805441
# std       6419.603169
# min      -2000.000000
# 25%       2000.000000
# 50%       5000.000000
# 75%       7500.000000
# max      96399.000000
# dtype: float64

# %%
df.shape
# Out:
# (30000, 28)

# %%
df[cat_non_ord_cols].nunique()
# Out:
# shift                2
# gender               3
# dow                  7
# employer_type        5
# city                 7
# area              2740
# organization     14886
# category            67
# is_part_time         2
# dtype: int64

# %%
df[cat_ordinal_cols].nunique()
# Out:
# applicant_location    4
# english               4
# education             6
# dtype: int64

# %% [markdown]
# ### Adding cat-cat interactions

# %%
def get_derived_cat(df,a,b):
    df[a+'_'+b]= df[a].astype('str') + '_' + df[b].astype('str')
    return df

# %%
def gen_cat_cat(df):
    df = get_derived_cat(df,'category','organization')
    df = get_derived_cat(df,'category','area')
    df = get_derived_cat(df,'category','city')
    df = get_derived_cat(df,'category','dow')
    df = get_derived_cat(df,'category','employer_type')
    
    df = get_derived_cat(df,'organization','area')
    df = get_derived_cat(df,'organization','city')
    df = get_derived_cat(df,'organization','dow')
    df = get_derived_cat(df,'organization','employer_type')
    
    df = get_derived_cat(df,'area','city')
    df = get_derived_cat(df,'area','dow')
    df = get_derived_cat(df,'area','employer_type')
    
    df = get_derived_cat(df,'city','dow')
    df = get_derived_cat(df,'city','employer_type')
    
    df = get_derived_cat(df,'dow','employer_type')
    
    df['cat_city_dow'] = df['category'].astype('str') + '_' + df['city'].astype('str') + '_' + df['dow'].astype('str')
    
    return df

# %%
df = gen_cat_cat(df)

# %%
cat_cat_cols = ['category_organization', 'category_area', 'category_city', 'category_dow',
                'category_employer_type', 'organization_area', 'organization_city', 'organization_dow', 
                'organization_employer_type', 'area_city', 'area_dow', 'area_employer_type', 'city_dow',
               'city_employer_type', 'dow_employer_type','cat_city_dow']

# %%
fe2 = FreqEnc(cat_freq_cols=['category_city'])

df = fe2.fit_transform(df)

# %%
class CatNumAgg:
    def __init__(self,agg_cols, agg_funcs, grpby_cols):
        self.agg_cols=agg_cols
        self.agg_funcs=agg_funcs
        self.grpby_cols=grpby_cols
    def fit(self,df):
        self.encoding_dict={}
        for grp_col in self.grpby_cols:
            agg_df = df.groupby(grp_col)[self.agg_cols].agg(self.agg_funcs).reset_index()
            agg_df.columns = [grp_col] + [
                i + "_" + j + "_grpby" + "_and_" + grp_col
                for i in self.agg_cols
                for j in self.agg_funcs
            ]
            self.encoding_dict[grp_col]=agg_df.to_dict()
    def transform(self,df):
        for k in self.encoding_dict:
            agg_df = pd.DataFrame(self.encoding_dict[k])
            df = df.merge(agg_df, on=k, how="left")
        return df
    def fit_transform(self,df):
        self.fit(df)
        return self.transform(df)

# %%
imp_num_cols = ['num_openings','max_salary','min_salary','education','applicant_location']
agg_funcs = ['mean','std','min','max','median']
cat_agg_cols = ['category','organization','area','category_city',
                'category_dow','city',
                'employer_type',
               ]

# %%
catnumagg = CatNumAgg(agg_cols= imp_num_cols,agg_funcs=agg_funcs, grpby_cols=cat_agg_cols)

# %%
df = catnumagg.fit_transform(df)

# %%
df.shape
# Out:
# (30000, 220)

# %%
from sklearn.decomposition import TruncatedSVD
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

class SVDClusterFeats:
    def __init__(self,n_components,n_clusters,random_state):
        self.scaler = StandardScaler()
        self.svd = TruncatedSVD(n_components=n_components,random_state=random_state)
        self.cluster = KMeans(n_clusters = n_clusters,random_state=random_state)
    
    def fit(self,X):
        X = self.scaler.fit_transform(X)
        X = np.nan_to_num(X,nan=0)
        self.svd.fit(X)
        self.cluster.fit(X)
    
    def transform(self,X):
        X = self.scaler.transform(X)
        X = np.nan_to_num(X,nan=0)
        svd_feats = self.svd.transform(X)
        cluster_feats = np.concatenate((self.cluster.transform(X),self.cluster.predict(X).reshape(-1,1)),axis=1)
        return svd_feats,cluster_feats
    
    def fit_transform(self,X):
        self.fit(X)
        return self.transform(X)

# %%
clust_cols = ['num_openings', 'max_salary', 'education', 'applicant_location'] + cat_cols

# %%
from kneed import KneeLocator
wcss =[]
for i in range(1, 20):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=0)
    kmeans.fit(df[clust_cols])
    wcss.append(kmeans.inertia_)
kn = KneeLocator(range(1, 20), wcss,  # put range in variable
curve='convex',
direction='decreasing', interp_method='interp1d')
print(kn.knee)
# Out:
# 5

# %%
plt.plot(range(1,20),wcss)

# %%
svd_clust = SVDClusterFeats(n_components=7,n_clusters=5,random_state=100)
svd_feats,clust_feats = svd_clust.fit_transform(df[clust_cols])
all_feats = np.hstack([svd_feats,clust_feats])
all_feats = pd.DataFrame(all_feats,columns=['svd_'+str(i) for i in range(svd_feats.shape[1])] + \
            ['clust_'+str(i) for i in range(clust_feats.shape[1])])

# %%
df = pd.concat([df,all_feats],1)
df.shape
# Out:
# (30000, 216)

# %%
# df['dow_6'] = (df['dow']==6).astype('int')
# df['city_6'] = (df['city']==6).astype('int')

# %%
uniq_cols = df.columns[df.nunique(dropna=False)==1]
len(uniq_cols)
# Out:
# 0

# %%
df.drop(uniq_cols,axis=1,inplace=True)

# %%
remove_cols = cat_non_ord_cols + ['target','leads_per_opening'] + cat_cat_cols
use_cols = [i for i in df.columns if i not in remove_cols]

# %%
params = {'boosting_type': 'gbdt',
 'colsample_bytree': 0.8,
 'learning_rate': 0.1,
 'min_child_samples': 120,
 'n_estimators': 10000,
 'n_jobs': -1,
 'num_leaves': 16,
 'objective': 'regression',
 'subsample': 0.8,
 'subsample_freq': 10}

# %%
est = Estimator(model=LGBMRegressor(**params),
               early_stopping_rounds=100,
               validation_scheme=folds,
               shuffle=True)

# %%
est.get_repeated_out_of_folds(df[use_cols].values,target)
# Out:
# [100]	valid_0's rmse: 0.900549	valid_0's l2: 0.810988	valid_1's rmse: 0.802114	valid_1's l2: 0.643386
# [200]	valid_0's rmse: 0.898932	valid_0's l2: 0.808079	valid_1's rmse: 0.749866	valid_1's l2: 0.5623
# [100]	valid_0's rmse: 0.84279	valid_0's l2: 0.710295	valid_1's rmse: 0.803742	valid_1's l2: 0.646
# [200]	valid_0's rmse: 0.839443	valid_0's l2: 0.704665	valid_1's rmse: 0.750061	valid_1's l2: 0.562592
# [100]	valid_0's rmse: 0.879399	valid_0's l2: 0.773342	valid_1's rmse: 0.800706	valid_1's l2: 0.64113
# [200]	valid_0's rmse: 0.872146	valid_0's l2: 0.760639	valid_1's rmse: 0.746139	valid_1's l2: 0.556724
# [300]	valid_0's rmse: 0.87159	valid_0's l2: 0.759669	valid_1's rmse: 0.706468	valid_1's l2: 0.499097
# {'cv_scores': [0.89753617997342, 0.8388878431240244, 0.8695252878371212],
#  'avg_cv_score': 0.8686497703115218,
#  'std_scores': 0.02395108559826694,
#  'overall_cv_score': 1.7149067543689938,
#  'eval_score': 0.8686497703115218}

# %%
feat_imps = est.feature_importances(columns = use_cols) 
feat_imps['cum_imp']=feat_imps.feature_importance.cumsum()
feat_imps
# Out:
#                                                 column  feature_importance  rank   cum_imp
# 5                                         num_openings            0.038924     1  0.038924
# 6                                           max_salary            0.037285     2  0.076209
# 1                                           created_on            0.030561     3  0.106770
# 177                                              svd_1            0.022753     4  0.129524
# 4                                              english            0.020135     5  0.149659
# 82                        education_std_grpby_and_area            0.019914     6  0.169573
# 111    applicant_location_mean_grpby_and_category_city            0.017237     7  0.186810
# 42             num_openings_std_grpby_and_organization            0.016261     8  0.203071
# 77                       min_salary_std_grpby_and_area            0.015719     9  0.218790
# 91           num_openings_mean_grpby_and_category_city            0.015321    10  0.234112
# 181                                              svd_5            0.015212    11  0.249324
# 38          applicant_location_mean_grpby_and_category            0.014941    12  0.264265
# 67                     num_openings_std_grpby_and_area            0.014536    13  0.278800
# 48               max_salary_min_grpby_and_organization            0.014238    14  0.293039
# 47               max_salary_std_grpby_and_organization            0.014215    15  0.307253
# 0                                            education            0.013608    16  0.320862
# 72                       max_salary_std_grpby_and_area            0.012822    17  0.333683
# 185                                            clust_2            0.012561    18  0.346245
# 176                                              svd_0            0.012204    19  0.358448
# 14                                     organization_fe            0.011868    20  0.370317
# 41            num_openings_mean_grpby_and_organization            0.011861    21  0.382178
# 76                      min_salary_mean_grpby_and_area            0.011808    22  0.393986
# 57                education_std_grpby_and_organization            0.011647    23  0.405633
# 15                                         category_fe            0.011463    24  0.417096
# 178                                              svd_2            0.011177    25  0.428273
# 106             education_mean_grpby_and_category_city            0.011143    26  0.439416
# 184                                            clust_1            0.011141    27  0.450557
# 180                                              svd_4            0.011068    28  0.461625
# 46              max_salary_mean_grpby_and_organization            0.011031    29  0.472657
# 112     applicant_location_std_grpby_and_category_city            0.010985    30  0.483642
# 102             min_salary_std_grpby_and_category_city            0.010266    31  0.493908
# 179                                              svd_3            0.010020    32  0.503929
# 107              education_std_grpby_and_category_city            0.009895    33  0.513823
# 81                       education_mean_grpby_and_area            0.009798    34  0.523621
# 17                                    category_city_fe            0.009697    35  0.533318
# 182                                              svd_6            0.009552    36  0.542870
# 183                                            clust_0            0.009550    37  0.552420
# 66                    num_openings_mean_grpby_and_area            0.009451    38  0.561871
# 87               applicant_location_std_grpby_and_area            0.009157    39  0.571029
# 13                                             area_fe            0.009084    40  0.580113
# 96             max_salary_mean_grpby_and_category_city            0.008907    41  0.589020
# 97              max_salary_std_grpby_and_category_city            0.008711    42  0.597730
# 92            num_openings_std_grpby_and_category_city            0.008662    43  0.606393
# 33                   education_mean_grpby_and_category            0.008660    44  0.615053
# 137      applicant_location_std_grpby_and_category_dow            0.008365    45  0.623418
# 71                      max_salary_mean_grpby_and_area            0.008192    46  0.631610
# 127              min_salary_std_grpby_and_category_dow            0.008058    47  0.639668
# 131              education_mean_grpby_and_category_dow            0.007871    48  0.647539
# 122              max_salary_std_grpby_and_category_dow            0.007676    49  0.655215
# 126             min_salary_mean_grpby_and_category_dow            0.007529    50  0.662744
# 132               education_std_grpby_and_category_dow            0.007365    51  0.670110
# 86              applicant_location_mean_grpby_and_area            0.007307    52  0.677416
# 78                       min_salary_min_grpby_and_area            0.007268    53  0.684685
# 25                   max_salary_min_grpby_and_category            0.007170    54  0.691854
# 101            min_salary_mean_grpby_and_category_city            0.006924    55  0.698778
# 136     applicant_location_mean_grpby_and_category_dow            0.006909    56  0.705686
# 49               max_salary_max_grpby_and_organization            0.006824    57  0.712510
# 186                                            clust_3            0.006800    58  0.719310
# 50            max_salary_median_grpby_and_organization            0.006773    59  0.726084
# 121             max_salary_mean_grpby_and_category_dow            0.006736    60  0.732820
# 62       applicant_location_std_grpby_and_organization            0.006712    61  0.739532
# 80                    min_salary_median_grpby_and_area            0.006652    62  0.746183
# 39           applicant_location_std_grpby_and_category            0.006391    63  0.752574
# 28                  min_salary_mean_grpby_and_category            0.006231    64  0.758805
# 117            num_openings_std_grpby_and_category_dow            0.006046    65  0.764851
# 19                 num_openings_std_grpby_and_category            0.005972    66  0.770824
# 157             applicant_location_mean_grpby_and_city            0.005873    67  0.776697
# 36                    education_max_grpby_and_category            0.005836    68  0.782533
# 56               education_mean_grpby_and_organization            0.005331    69  0.787864
# 187                                            clust_4            0.005221    70  0.793085
# 29                   min_salary_std_grpby_and_category            0.005096    71  0.798181
# 100          max_salary_median_grpby_and_category_city            0.005046    72  0.803227
# 45          num_openings_median_grpby_and_organization            0.004998    73  0.808226
# 116           num_openings_mean_grpby_and_category_dow            0.004961    74  0.813186
# 23                  max_salary_mean_grpby_and_category            0.004960    75  0.818147
# 75                    max_salary_median_grpby_and_area            0.004762    76  0.822909
# 59                education_max_grpby_and_organization            0.004700    77  0.827609
# 104             min_salary_max_grpby_and_category_city            0.004678    78  0.832287
# 44             num_openings_max_grpby_and_organization            0.004577    79  0.836865
# 31                   min_salary_max_grpby_and_category            0.004552    80  0.841417
# 79                       min_salary_max_grpby_and_area            0.004468    81  0.845885
# 98              max_salary_min_grpby_and_category_city            0.004456    82  0.850341
# 73                       max_salary_min_grpby_and_area            0.004430    83  0.854771
# 55            min_salary_median_grpby_and_organization            0.004281    84  0.859051
# 70                  num_openings_median_grpby_and_area            0.004197    85  0.863248
# 105          min_salary_median_grpby_and_category_city            0.004158    86  0.867406
# 9                                            gender_fe            0.004108    87  0.871514
# 99              max_salary_max_grpby_and_category_city            0.004010    88  0.875524
# 145                      max_salary_std_grpby_and_city            0.003948    89  0.879472
# 12                                             city_fe            0.003898    90  0.883370
# 51              min_salary_mean_grpby_and_organization            0.003825    91  0.887195
# 94            num_openings_max_grpby_and_category_city            0.003824    92  0.891019
# 52               min_salary_std_grpby_and_organization            0.003726    93  0.894746
# 103             min_salary_min_grpby_and_category_city            0.003628    94  0.898373
# 130           min_salary_median_grpby_and_category_dow            0.003554    95  0.901927
# 18                num_openings_mean_grpby_and_category            0.003442    96  0.905369
# 74                       max_salary_max_grpby_and_area            0.003418    97  0.908787
# 24                   max_salary_std_grpby_and_category            0.003333    98  0.912119
# 64       applicant_location_max_grpby_and_organization            0.003269    99  0.915389
# 188                                            clust_5            0.003244   100  0.918633
# 53               min_salary_min_grpby_and_organization            0.003148   101  0.921781
# 143                 num_openings_median_grpby_and_city            0.003109   102  0.924889
# 43             num_openings_min_grpby_and_organization            0.002985   103  0.927874
# 128              min_salary_min_grpby_and_category_dow            0.002949   104  0.930824
# 69                     num_openings_max_grpby_and_area            0.002938   105  0.933761
# 54               min_salary_max_grpby_and_organization            0.002925   106  0.936686
# 26                   max_salary_max_grpby_and_category            0.002887   107  0.939573
# 21                 num_openings_max_grpby_and_category            0.002652   108  0.942225
# 123              max_salary_min_grpby_and_category_dow            0.002604   109  0.944829
# 30                   min_salary_min_grpby_and_category            0.002517   110  0.947346
# 129              min_salary_max_grpby_and_category_dow            0.002505   111  0.949851
# 34                    education_std_grpby_and_category            0.002456   112  0.952307
# 124              max_salary_max_grpby_and_category_dow            0.002309   113  0.954616
# 10                                              dow_fe            0.002271   114  0.956888
# 141                   num_openings_mean_grpby_and_city            0.002221   115  0.959109
# 61      applicant_location_mean_grpby_and_organization            0.002209   116  0.961318
# 22              num_openings_median_grpby_and_category            0.002059   117  0.963377
# 32                min_salary_median_grpby_and_category            0.001888   118  0.965265
# 95         num_openings_median_grpby_and_category_city            0.001814   119  0.967079
# 7                                           min_salary            0.001679   120  0.968758
# 2                                   applicant_location            0.001629   121  0.970387
# 144                     max_salary_mean_grpby_and_city            0.001517   122  0.971904
# 155                       education_std_grpby_and_city            0.001258   123  0.973162
# 60             education_median_grpby_and_organization            0.001247   124  0.974409
# 120         num_openings_median_grpby_and_category_dow            0.001234   125  0.975643
# 169             min_salary_min_grpby_and_employer_type            0.001185   126  0.976828
# 11                                    employer_type_fe            0.001172   127  0.978000
# 27                max_salary_median_grpby_and_category            0.001086   128  0.979086
# 150                      min_salary_std_grpby_and_city            0.001073   129  0.980159
# 89               applicant_location_max_grpby_and_area            0.001060   130  0.981220
# 85                     education_median_grpby_and_area            0.001036   131  0.982256
# 174    applicant_location_mean_grpby_and_employer_type            0.001036   132  0.983292
# 110           education_median_grpby_and_category_city            0.001023   133  0.984315
# 58                education_min_grpby_and_organization            0.000987   134  0.985303
# 167            min_salary_mean_grpby_and_employer_type            0.000987   135  0.986290
# 125           max_salary_median_grpby_and_category_dow            0.000987   136  0.987277
# 142                    num_openings_std_grpby_and_city            0.000950   137  0.988227
# 139      applicant_location_max_grpby_and_category_dow            0.000864   138  0.989091
# 65    applicant_location_median_grpby_and_organization            0.000815   139  0.989906
# 108              education_min_grpby_and_category_city            0.000802   140  0.990708
# 159          num_openings_mean_grpby_and_employer_type            0.000778   141  0.991486
# 114     applicant_location_max_grpby_and_category_city            0.000740   142  0.992226
# 84                        education_max_grpby_and_area            0.000716   143  0.992943
# 134               education_max_grpby_and_category_dow            0.000691   144  0.993633
# 173              education_std_grpby_and_employer_type            0.000666   145  0.994299
# 158              applicant_location_std_grpby_and_city            0.000604   146  0.994904
# 163             max_salary_std_grpby_and_employer_type            0.000604   147  0.995508
# 119            num_openings_max_grpby_and_category_dow            0.000593   148  0.996101
# 90            applicant_location_median_grpby_and_area            0.000567   149  0.996668
# 146                      max_salary_min_grpby_and_city            0.000518   150  0.997187
# 168             min_salary_std_grpby_and_employer_type            0.000394   151  0.997581
# 135            education_median_grpby_and_category_dow            0.000383   152  0.997964
# 63       applicant_location_min_grpby_and_organization            0.000346   153  0.998310
# 133               education_min_grpby_and_category_dow            0.000259   154  0.998569
# 152                      min_salary_max_grpby_and_city            0.000222   155  0.998791
# 37                 education_median_grpby_and_category            0.000210   156  0.999001
# 109              education_max_grpby_and_category_city            0.000173   157  0.999174
# 148                   max_salary_median_grpby_and_city            0.000136   158  0.999309
# 160           num_openings_std_grpby_and_employer_type            0.000136   159  0.999445
# 164             max_salary_min_grpby_and_employer_type            0.000136   160  0.999580
# 83                        education_min_grpby_and_area            0.000123   161  0.999704
# 175     applicant_location_std_grpby_and_employer_type            0.000123   162  0.999827
# 147                      max_salary_max_grpby_and_city            0.000086   163  0.999914
# 170             min_salary_max_grpby_and_employer_type            0.000086   164  1.000000
# 118            num_openings_min_grpby_and_category_dow            0.000000   165  1.000000
# 115  applicant_location_median_grpby_and_category_city            0.000000   166  1.000000
# 149                     min_salary_mean_grpby_and_city            0.000000   167  1.000000
# 113     applicant_location_min_grpby_and_category_city            0.000000   168  1.000000
# 20                 num_openings_min_grpby_and_category            0.000000   169  1.000000
# 68                     num_openings_min_grpby_and_area            0.000000   170  1.000000
# 8                                             shift_fe            0.000000   171  1.000000
# 3                                              deposit            0.000000   172  1.000000
# 88               applicant_location_min_grpby_and_area            0.000000   173  1.000000
# 16                                     is_part_time_fe            0.000000   174  1.000000
# 35                    education_min_grpby_and_category            0.000000   175  1.000000
# 40           applicant_location_max_grpby_and_category            0.000000   176  1.000000
# 172             education_mean_grpby_and_employer_type            0.000000   177  1.000000
# 171          min_salary_median_grpby_and_employer_type            0.000000   178  1.000000
# 166          max_salary_median_grpby_and_employer_type            0.000000   179  1.000000
# 165             max_salary_max_grpby_and_employer_type            0.000000   180  1.000000
# 162            max_salary_mean_grpby_and_employer_type            0.000000   181  1.000000
# 161        num_openings_median_grpby_and_employer_type            0.000000   182  1.000000
# 138      applicant_location_min_grpby_and_category_dow            0.000000   183  1.000000
# 93            num_openings_min_grpby_and_category_city            0.000000   184  1.000000
# 156                    education_median_grpby_and_city            0.000000   185  1.000000
# 154                      education_mean_grpby_and_city            0.000000   186  1.000000
# 153                   min_salary_median_grpby_and_city            0.000000   187  1.000000
# 151                      min_salary_min_grpby_and_city            0.000000   188  1.000000
# 140   applicant_location_median_grpby_and_category_dow            0.000000   189  1.000000

# %% [markdown]
# ### Important variables that could be used for further feature engineering in order of importance

# %% [markdown]
# 1. category,area, organization, city, dow
# 2. created_on, max_salary, num_openings, min_salary
# 3. education,english
# 4. employer type
